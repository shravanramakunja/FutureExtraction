# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns

# %%
df=pd.read_csv('Countries.csv')
df
# Out:
#                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.head(1)
# Out:
#        country                  country_long        currency capital_city  \
# 0  Afghanistan  Islamic State of Afghanistan  Afghan afghani        Kabul
#
#           region continent demonym  latitude  longitude  agricultural_land  \
# 0  Southern Asia      Asia  Afghan      33.0       65.0           383560.0
#
#    ...  population  women_parliament_seats_pct  rural_population  \
# 0  ...    41128771                     27.0161          30181937
#
#    urban_population  press  democracy_score  democracy_type  median_age  \
# 0          10946834   2.14             2.97   Authoritarian        12.9
#
#    political_leader      title
# 0      Ashraf Ghani  President
#
# [1 rows x 64 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of                 country                             country_long  \
# 0           Afghanistan             Islamic State of Afghanistan
# 1               Albania                      Republic of Albania
# 2               Algeria  People's Democratic Republic of Algeria
# 3               Andorra                  Principality of Andorra
# 4                Angola              People's Republic of Angola
# ..                  ...                                      ...
# 189             Vietnam            Socialist Republic of Vietnam
# 190  West Bank and Gaza                       West Bank and Gaza
# 191               Yemen                        Republic of Yemen
# 192              Zambia                       Republic of Zambia
# 193            Zimbabwe                     Republic of Zimbabwe
#
#                currency      capital_city              region continent  \
# 0        Afghan afghani             Kabul       Southern Asia      Asia
# ...

# %%
df.describe()
# Out:
#          latitude   longitude  agricultural_land   forest_area     land_area  \
# count  194.000000  194.000000       1.930000e+02  1.940000e+02  1.940000e+02
# mean    18.975601   22.027491       2.454551e+05  2.086784e+05  6.675087e+05
# std     23.876225   66.396389       6.356268e+05  7.824926e+05  1.837107e+06
# min    -41.000000 -175.000000       4.000000e+00  0.000000e+00  2.027000e+00
# 25%      4.000000   -5.000000       6.464000e+03  3.331775e+03  2.355250e+04
# 50%     16.583333   21.500000       3.872780e+04  2.528925e+04  1.203750e+05
# 75%     40.000000   50.162500       2.150000e+05  1.236735e+05  5.237000e+05
# max     65.000000  178.000000       5.285080e+06  8.153120e+06  1.637690e+07
#
#          rural_land     urban_land  central_government_debt_pct_gdp  \
# count  1.940000e+02     194.000000                       120.000000
# mean   6.563711e+05    9777.116531                        66.759366
# std    1.811169e+06   42301.458421                        71.806247
# ...

# %%
df.head(2)
# Out:
#        country                  country_long        currency capital_city  \
# 0  Afghanistan  Islamic State of Afghanistan  Afghan afghani        Kabul
# 1      Albania           Republic of Albania    Albanian lek       Tirana
#
#             region continent   demonym  latitude  longitude  \
# 0    Southern Asia      Asia    Afghan      33.0       65.0
# 1  Southern Europe    Europe  Albanian      41.0       20.0
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                     27.0161
# 1            11655.5  ...     2775634                     35.7143
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# 0          30181937          10946834   2.14             2.97   Authoritarian
# 1           1004807           1770827   2.62             5.98   Hybrid regime
#
#    median_age  political_leader           title
# 0        12.9      Ashraf Ghani       President
# ...

# %%
 #to extract only the country the population 
count=df[['country','population']].sort_values(by='population',ascending=False).head(5)
count
# Out:
#            country  population
# 75           India  1417173173
# 34           China  1412175000
# 184  United States   333287557
# 76       Indonesia   275501339
# 129       Pakistan   235824862

# %%
sns.barplot(x='country',y='population',data=count)
plt.title("Population Count")
# Out:
# Text(0.5, 1.0, 'Population Count')

# %%
score=df[['country','democracy_score']].sort_values(by='democracy_score',ascending=False).head(5)
score
# Out:
#          country  democracy_score
# 127       Norway             9.87
# 74       Iceland             9.58
# 164       Sweden             9.39
# 122  New Zealand             9.26
# 46       Denmark             9.22

# %%
sns.barplot(x='democracy_score',y='country',data=count,palette='mako')
plt.title( "Democracy Score")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 sns.barplot(x='democracy_score',y='country',data=count,palette='mako')
#       2 plt.title( "Democracy Score")
#
# File ~\AppData\Local\Programs\Python\Python312\Lib\site-packages\seaborn\categorical.py:2341, in barplot(data, x, y, hue, order, hue_order, estimator, errorbar, n_boot, seed, units, weights, orient, color, palette, saturation, fill, hue_norm, width, dodge, gap, log_scale, native_scale, formatter, legend, capsize, err_kws, ci, errcolor, errwidth, ax, **kwargs)
#    2338 if estimator is len:
#    2339     estimator = "size"
# -> 2341 p = _CategoricalAggPlotter(
#    2342     data=data,
#    2343     variables=dict(x=x, y=y, hue=hue, units=units, weight=weights),
#    2344     order=order,
#    2345     orient=orient,
#    2346     color=color,
#    2347     legend=legend,
#    2348 )
# ...

# %%
df.head(3)
# Out:
#        country                             country_long        currency  \
# 0  Afghanistan             Islamic State of Afghanistan  Afghan afghani
# 1      Albania                      Republic of Albania    Albanian lek
# 2      Algeria  People's Democratic Republic of Algeria  Algerian dinar
#
#   capital_city           region continent   demonym  latitude  longitude  \
# 0        Kabul    Southern Asia      Asia    Afghan      33.0       65.0
# 1       Tirana  Southern Europe    Europe  Albanian      41.0       20.0
# 2      Algiers  Northern Africa    Africa  Algerian      28.0        3.0
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                    27.01610
# 1            11655.5  ...     2775634                    35.71430
# 2           413588.0  ...    44903225                     8.10811
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 194 entries, 0 to 193
# Data columns (total 64 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   country                                  194 non-null    object
#  1   country_long                             194 non-null    object
#  2   currency                                 194 non-null    object
#  3   capital_city                             194 non-null    object
#  4   region                                   194 non-null    object
#  5   continent                                194 non-null    object
#  6   demonym                                  194 non-null    object
#  7   latitude                                 194 non-null    float64
#  8   longitude                                194 non-null    float64
#  9   agricultural_land                        193 non-null    float64
# ...

# %%
heatmap=df[['population','rural_population','urban_population']].head(5)

# %%
heatmap
# Out:
#    population  rural_population  urban_population
# 0    41128771          30181937          10946834
# 1     2775634           1004807           1770827
# 2    44903225          11328186          33575039
# 3       79824              9730             70094
# 4    35588987          11359649          24229338

# %%
sns.heatmap(heatmap,annot=True)
# Out:
# <Axes: >

# %%
sns.heatmap(heatmap.isnull())
# Out:
# <Axes: >

# %%
df.head(2)
# Out:
#        country                  country_long        currency capital_city  \
# 0  Afghanistan  Islamic State of Afghanistan  Afghan afghani        Kabul
# 1      Albania           Republic of Albania    Albanian lek       Tirana
#
#             region continent   demonym  latitude  longitude  \
# 0    Southern Asia      Asia    Afghan      33.0       65.0
# 1  Southern Europe    Europe  Albanian      41.0       20.0
#
#    agricultural_land  ...  population  women_parliament_seats_pct  \
# 0           383560.0  ...    41128771                     27.0161
# 1            11655.5  ...     2775634                     35.7143
#
#    rural_population  urban_population  press  democracy_score  democracy_type  \
# 0          30181937          10946834   2.14             2.97   Authoritarian
# 1           1004807           1770827   2.62             5.98   Hybrid regime
#
#    median_age  political_leader           title
# 0        12.9      Ashraf Ghani       President
# ...

# %%
sns.scatterplot(x='rural_population',y='urban_population',data=df)
# Out:
# <Axes: xlabel='rural_population', ylabel='urban_population'>

# %%
sns.scatterplot(x='longitude',y='latitude',data=df)
# Out:
# <Axes: xlabel='longitude', ylabel='latitude'>

# %%
sns.barplot(x='country',y="population",data=df)
# Out:
# <Axes: xlabel='country', ylabel='population'>

# %%
countries=df.sort_values(by='population',ascending=False).head(5)
countries
# Out:
#            country                  country_long           currency  \
# 75           India             Republic of India       Indian rupee
# 34           China    People's Republic of China       Chinese yuan
# 184  United States      United States of America        U.S. dollar
# 76       Indonesia         Republic of Indonesia  Indonesian rupiah
# 129       Pakistan  Islamic Republic of Pakistan    Pakistani rupee
#
#          capital_city              region continent     demonym  latitude  \
# 75          New Delhi       Southern Asia      Asia      Indian      20.0
# 34            Beijing        Eastern Asia      Asia     Chinese      35.0
# 184  Washington, D.C.    Northern America  Americas    American      38.0
# 76            Jakarta  South-Eastern Asia      Asia  Indonesian      -5.0
# 129         Islamabad       Southern Asia      Asia   Pakistani      30.0
#
#      longitude  agricultural_land  ...  population  \
# 75        77.0          1790450.0  ...  1417173173
# ...

# %%
sns.barplot(x='country',y="population",data=countries)
# Out:
# <Axes: xlabel='country', ylabel='population'>
